# %%
import pandas as pd

# %%
df = pd.read_parquet("breastcancer.parquet")

# %%
len(df)
# Out:
# 409231

# %%
import matplotlib.pyplot as plt
df["forum"].value_counts()[::-1].plot.barh()
# Out:
# <Axes: ylabel='forum'>

# %% [markdown]
# # Too long, only use posts starting 2020

# %%
df2020 = df[df["time"].dt.year >= 2020]

# %%
len(df2020)
# Out:
# 41812

# %%
df2020["forum"].value_counts()[::-1].plot.barh()
# Out:
# <Axes: ylabel='forum'>

# %%
df2020["author"].unique()
# Out:
# array(['WC3', 'hope70', 'Drcharlottetottman', ..., 'mzg', 'Tulipsfordayz',
#        'moneeme'], shape=(2990,), dtype=object)

# %%
df2020["author"].value_counts()[0:20][::-1].plot.barh()
