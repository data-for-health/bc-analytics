# %%
import pandas as pd

# %%
df = pd.read_parquet("breastcancer.parquet")

# %%
import matplotlib.pyplot as plt
df["forum"].value_counts()[::-1].plot.barh()
# Out:
# <Axes: ylabel='forum'>

# %%
df["author"].nunique()
# Out:
# 14637

# %%
df2020 = df[df["time"].dt.year >= 2020]

# %%
df2020["forum"].value_counts()[::-1].plot.barh()
# Out:
# <Axes: ylabel='forum'>

# %%
df2020["author"].nunique()
# Out:
# 2990

# %%
df2020["author"].value_counts()[0:30][::-1].plot.barh()
# Out:
# <Axes: ylabel='author'>
